# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split as split
import os


df = pd.read_csv('MHR.csv')
df.head(5)

import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def num_plot(df, col):
    fig, ax = plt.subplots(1, 2, figsize=(12, 4))
    sns.histplot(data=df, x=col, kde=True, ax=ax[0])
    sns.boxplot(data=df, x=col, ax=ax[1])
    ax[0].set_title(f"{col} Distribution Histogram")
    ax[1].set_title(f"{col} Distribution Boxplot")
    plt.show()

num_plot(df, "Age")
num_plot(df, "SystolicBP")
num_plot(df, "DiastolicBP")
num_plot(df, "BS")
num_plot(df, "BodyTemp")
num_plot(df, "HeartRate")

# Exclude the 'RiskLevel' column from the correlation matrix
numerical_df = df.drop(columns=['RiskLevel'])

sns.heatmap(numerical_df.corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

sns.pairplot(df)
plt.show()

p_colors = ['forestgreen', 'gold', 'red']
risk_order = ["low risk", "mid risk", "high risk"]

sns.histplot(data=df, x="Age", hue="RiskLevel", kde=True, hue_order=risk_order, palette=p_colors)
plt.show()

pd.crosstab(df.RiskLevel, df.Age).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_f143b_row0_col0, #T_f143b_row0_col1, #T_f143b_row0_col4, #T_f143b_row0_col5, #T_f143b_row0_col7, #T_f143b_row0_col8, #T_f143b_row0_col9, #T_f143b_row0_col10, #T_f143b_row0_col11, #T_f143b_row0_col12, #T_f143b_row0_col13, #T_f143b_row0_col15, #T_f143b_row0_col16, #T_f143b_row0_col17, #T_f143b_row0_col20, #T_f143b_row0_col30, #T_f143b_row0_col31, #T_f143b_row0_col33, #T_f143b_row0_col37, #T_f143b_row0_col39, #T_f143b_row0_col43, #T_f143b_row0_col44, #T_f143b_row0_col45, #T_f143b_row0_col48, #T_f143b_row0_col49, #T_f143b_row1_col2, #T_f143b_row1_col3, #T_f143b_row1_col6, #T_f143b_row1_col15, #T_f143b_row1_col18, #T_f143b_row1_col19, #T_f143b_row1_col22, #T_f143b_row1_col25, #T_f143b_row1_col26, #T_f143b_row1_col27, #T_f143b_row1_col28, #T_f143b_row1_col29, #T_f143b_row1_col32, #T_f143b_row1_col33, #T_f143b_row1_col35, #T_f143b_row1_col36, #T_f143b_row1_col38, #T_f143b_row1_col40, #T_f143b_row1_col42, #T_f143b_row1_col46, #T_f143b_row2_col3, #T_f143b_row2_col13, #T_f143b_row2_col14, #T_f143b_row2_col16, #T_f143b_row2_col21, #T_f143b_row2_col23, #T_f143b_row2_col24, #T_f143b_row2_col26, #T_f143b_row2_col27, #T_f143b_row2_col30, #T_f143b_row2_col31, #T_f143b_row2_col34, #T_f143b_row2_col35, #T_f143b_row2_col37, #T_f143b_row2_col39, #T_f143b_row2_col41, #T_f143b_row2_col42, #T_f143b_row2_col43, #T_f143b_row2_col45, #T_f143b_row2_col46, #T_f143b_row2_col47, #T_f143b_row2_col48, #T_f143b_row2_col49 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_f143b_row0_col2 {
#   background-color: #cce666;
#   color: #000000;
# }
# #T_f143b_row0_col3, #T_f143b_row0_col6, #T_f143b_row0_col14, #T_f143b_row0_col21, #T_f143b_row0_col23, #T_f143b_row0_col24, #T_f143b_row0_col25, #T_f143b_row0_col26, #T_f143b_row0_col27, #T_f143b_row0_col28, #T_f143b_row0_col29, #T_f143b_row0_col32, #T_f143b_row0_col35, #T_f143b_row0_col36, #T_f143b_row0_col38, #T_f143b_row0_col40, #T_f143b_row0_col41, #T_f143b_row0_col42, #T_f143b_row0_col46, #T_f143b_row1_col0, #T_f143b_row1_col1, #T_f143b_row1_col4, #T_f143b_row1_col5, #T_f143b_row1_col9, #T_f143b_row1_col10, #T_f143b_row1_col11, #T_f143b_row1_col12, #T_f143b_row1_col13, #T_f143b_row1_col16, #T_f143b_row1_col21, #T_f143b_row1_col30, #T_f143b_row1_col31, #T_f143b_row1_col34, #T_f143b_row1_col37, #T_f143b_row1_col39, #T_f143b_row1_col43, #T_f143b_row1_col45, #T_f143b_row1_col47, #T_f143b_row1_col48, #T_f143b_row1_col49, #T_f143b_row2_col0, #T_f143b_row2_col2, #T_f143b_row2_col7, #T_f143b_row2_col8, #T_f143b_row2_col9, #T_f143b_row2_col15, #T_f143b_row2_col17, #T_f143b_row2_col18, #T_f143b_row2_col19, #T_f143b_row2_col20, #T_f143b_row2_col22, #T_f143b_row2_col25, #T_f143b_row2_col28, #T_f143b_row2_col33, #T_f143b_row2_col44 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_f143b_row0_col18 {
#   background-color: #c9e466;
#   color: #000000;
# }
# #T_f143b_row0_col19, #T_f143b_row0_col47, #T_f143b_row1_col14, #T_f143b_row2_col6 {
#   background-color: #7fbf66;
#   color: #000000;
# }
# #T_f143b_row0_col22, #T_f143b_row1_col23, #T_f143b_row2_col32 {
#   background-color: #55aa66;
#   color: #f1f1f1;
# }
# #T_f143b_row0_col34 {
#   background-color: #dfef66;
#   color: #000000;
# }
# #T_f143b_row1_col7 {
#   background-color: #45a266;
#   color: #f1f1f1;
# }
# #T_f143b_row1_col8 {
#   background-color: #41a066;
#   color: #f1f1f1;
# }
# #T_f143b_row1_col17 {
#   background-color: #d1e866;
#   color: #000000;
# }
# #T_f143b_row1_col20 {
#   background-color: #88c366;
#   color: #000000;
# }
# #T_f143b_row1_col24 {
#   background-color: #118866;
#   color: #f1f1f1;
# }
# #T_f143b_row1_col41 {
#   background-color: #8ec666;
#   color: #000000;
# }
# #T_f143b_row1_col44 {
#   background-color: #249266;
#   color: #f1f1f1;
# }
# #T_f143b_row2_col1 {
#   background-color: #3f9f66;
#   color: #f1f1f1;
# }
# #T_f143b_row2_col4 {
#   background-color: #edf666;
#   color: #000000;
# }
# #T_f143b_row2_col5 {
#   background-color: #66b266;
#   color: #f1f1f1;
# }
# #T_f143b_row2_col10 {
#   background-color: #97cb66;
#   color: #000000;
# }
# #T_f143b_row2_col11 {
#   background-color: #b2d866;
#   color: #000000;
# }
# #T_f143b_row2_col12 {
#   background-color: #7cbe66;
#   color: #000000;
# }
# #T_f143b_row2_col29 {
#   background-color: #f8fc66;
#   color: #000000;
# }
# #T_f143b_row2_col36 {
#   background-color: #d5ea66;
#   color: #000000;
# }
# #T_f143b_row2_col38 {
#   background-color: #5aac66;
#   color: #f1f1f1;
# }
# #T_f143b_row2_col40 {
#   background-color: #aad466;
#   color: #000000;
# }
# </style>
# <table id="T_f143b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Age</th>
#       <th id="T_f143b_level0_col0" class="col_heading level0 col0" >10</th>
#       <th id="T_f143b_level0_col1" class="col_heading level0 col1" >12</th>
#       <th id="T_f143b_level0_col2" class="col_heading level0 col2" >13</th>
#       <th id="T_f143b_level0_col3" class="col_heading level0 col3" >14</th>
#       <th id="T_f143b_level0_col4" class="col_heading level0 col4" >15</th>
#       <th id="T_f143b_level0_col5" class="col_heading level0 col5" >16</th>
#       <th id="T_f143b_level0_col6" class="col_heading level0 col6" >17</th>
#       <th id="T_f143b_level0_col7" class="col_heading level0 col7" >18</th>
#       <th id="T_f143b_level0_col8" class="col_heading level0 col8" >19</th>
#       <th id="T_f143b_level0_col9" class="col_heading level0 col9" >20</th>
#       <th id="T_f143b_level0_col10" class="col_heading level0 col10" >21</th>
#       <th id="T_f143b_level0_col11" class="col_heading level0 col11" >22</th>
#       <th id="T_f143b_level0_col12" class="col_heading level0 col12" >23</th>
#       <th id="T_f143b_level0_col13" class="col_heading level0 col13" >24</th>
#       <th id="T_f143b_level0_col14" class="col_heading level0 col14" >25</th>
#       <th id="T_f143b_level0_col15" class="col_heading level0 col15" >26</th>
#       <th id="T_f143b_level0_col16" class="col_heading level0 col16" >27</th>
#       <th id="T_f143b_level0_col17" class="col_heading level0 col17" >28</th>
#       <th id="T_f143b_level0_col18" class="col_heading level0 col18" >29</th>
#       <th id="T_f143b_level0_col19" class="col_heading level0 col19" >30</th>
#       <th id="T_f143b_level0_col20" class="col_heading level0 col20" >31</th>
#       <th id="T_f143b_level0_col21" class="col_heading level0 col21" >32</th>
#       <th id="T_f143b_level0_col22" class="col_heading level0 col22" >33</th>
#       <th id="T_f143b_level0_col23" class="col_heading level0 col23" >34</th>
#       <th id="T_f143b_level0_col24" class="col_heading level0 col24" >35</th>
#       <th id="T_f143b_level0_col25" class="col_heading level0 col25" >36</th>
#       <th id="T_f143b_level0_col26" class="col_heading level0 col26" >37</th>
#       <th id="T_f143b_level0_col27" class="col_heading level0 col27" >38</th>
#       <th id="T_f143b_level0_col28" class="col_heading level0 col28" >39</th>
#       <th id="T_f143b_level0_col29" class="col_heading level0 col29" >40</th>
#       <th id="T_f143b_level0_col30" class="col_heading level0 col30" >41</th>
#       <th id="T_f143b_level0_col31" class="col_heading level0 col31" >42</th>
#       <th id="T_f143b_level0_col32" class="col_heading level0 col32" >43</th>
#       <th id="T_f143b_level0_col33" class="col_heading level0 col33" >44</th>
#       <th id="T_f143b_level0_col34" class="col_heading level0 col34" >45</th>
#       <th id="T_f143b_level0_col35" class="col_heading level0 col35" >46</th>
#       <th id="T_f143b_level0_col36" class="col_heading level0 col36" >48</th>
#       <th id="T_f143b_level0_col37" class="col_heading level0 col37" >49</th>
#       <th id="T_f143b_level0_col38" class="col_heading level0 col38" >50</th>
#       <th id="T_f143b_level0_col39" class="col_heading level0 col39" >51</th>
#       <th id="T_f143b_level0_col40" class="col_heading level0 col40" >54</th>
#       <th id="T_f143b_level0_col41" class="col_heading level0 col41" >55</th>
#       <th id="T_f143b_level0_col42" class="col_heading level0 col42" >56</th>
#       <th id="T_f143b_level0_col43" class="col_heading level0 col43" >59</th>
#       <th id="T_f143b_level0_col44" class="col_heading level0 col44" >60</th>
#       <th id="T_f143b_level0_col45" class="col_headin
