# %% [markdown]
# ####  Import Packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split as split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

import os
file_path = 'MHR.csv'

# %%
p_colors = ['darkgreen', 'darkorange', 'darkred']
risk_order = ["low risk", "mid risk", "high risk"]

# %% [markdown]
# #### Import Dataset

# %%
df = pd.read_csv(file_path)
df.head(5)
# Out:
#    Age  SystolicBP  DiastolicBP    BS  BodyTemp  HeartRate  RiskLevel
# 0   25         130           80  15.0      98.0         86  high risk
# 1   35         140           90  13.0      98.0         70  high risk
# 2   29          90           70   8.0     100.0         80  high risk
# 3   30         140           85   7.0      98.0         70  high risk
# 4   35         120           60   6.1      98.0         76   low risk

# %% [markdown]
# #### Predictor and Target
# We will use histogram with hue mapping to visualize the predictor variables data distribution based on the target variable. Also, since our predictor variable only has few unique values, we can also use pandas crosstab to see the detailed values.

# %% [markdown]
# ####  Age → RiskLevel

# %%
sns.histplot(data=df, x="Age", hue="RiskLevel", kde=True, hue_order=risk_order, palette=p_colors)
plt.show()

# %%
pd.crosstab(df.RiskLevel, df.Age).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_d3c23_row0_col0, #T_d3c23_row0_col1, #T_d3c23_row0_col4, #T_d3c23_row0_col5, #T_d3c23_row0_col7, #T_d3c23_row0_col8, #T_d3c23_row0_col9, #T_d3c23_row0_col10, #T_d3c23_row0_col11, #T_d3c23_row0_col12, #T_d3c23_row0_col13, #T_d3c23_row0_col15, #T_d3c23_row0_col16, #T_d3c23_row0_col17, #T_d3c23_row0_col20, #T_d3c23_row0_col30, #T_d3c23_row0_col31, #T_d3c23_row0_col33, #T_d3c23_row0_col37, #T_d3c23_row0_col39, #T_d3c23_row0_col43, #T_d3c23_row0_col44, #T_d3c23_row0_col45, #T_d3c23_row0_col48, #T_d3c23_row0_col49, #T_d3c23_row1_col2, #T_d3c23_row1_col3, #T_d3c23_row1_col6, #T_d3c23_row1_col15, #T_d3c23_row1_col18, #T_d3c23_row1_col19, #T_d3c23_row1_col22, #T_d3c23_row1_col25, #T_d3c23_row1_col26, #T_d3c23_row1_col27, #T_d3c23_row1_col28, #T_d3c23_row1_col29, #T_d3c23_row1_col32, #T_d3c23_row1_col33, #T_d3c23_row1_col35, #T_d3c23_row1_col36, #T_d3c23_row1_col38, #T_d3c23_row1_col40, #T_d3c23_row1_col42, #T_d3c23_row1_col46, #T_d3c23_row2_col3, #T_d3c23_row2_col13, #T_d3c23_row2_col14, #T_d3c23_row2_col16, #T_d3c23_row2_col21, #T_d3c23_row2_col23, #T_d3c23_row2_col24, #T_d3c23_row2_col26, #T_d3c23_row2_col27, #T_d3c23_row2_col30, #T_d3c23_row2_col31, #T_d3c23_row2_col34, #T_d3c23_row2_col35, #T_d3c23_row2_col37, #T_d3c23_row2_col39, #T_d3c23_row2_col41, #T_d3c23_row2_col42, #T_d3c23_row2_col43, #T_d3c23_row2_col45, #T_d3c23_row2_col46, #T_d3c23_row2_col47, #T_d3c23_row2_col48, #T_d3c23_row2_col49 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_d3c23_row0_col2 {
#   background-color: #cce666;
#   color: #000000;
# }
# #T_d3c23_row0_col3, #T_d3c23_row0_col6, #T_d3c23_row0_col14, #T_d3c23_row0_col21, #T_d3c23_row0_col23, #T_d3c23_row0_col24, #T_d3c23_row0_col25, #T_d3c23_row0_col26, #T_d3c23_row0_col27, #T_d3c23_row0_col28, #T_d3c23_row0_col29, #T_d3c23_row0_col32, #T_d3c23_row0_col35, #T_d3c23_row0_col36, #T_d3c23_row0_col38, #T_d3c23_row0_col40, #T_d3c23_row0_col41, #T_d3c23_row0_col42, #T_d3c23_row0_col46, #T_d3c23_row1_col0, #T_d3c23_row1_col1, #T_d3c23_row1_col4, #T_d3c23_row1_col5, #T_d3c23_row1_col9, #T_d3c23_row1_col10, #T_d3c23_row1_col11, #T_d3c23_row1_col12, #T_d3c23_row1_col13, #T_d3c23_row1_col16, #T_d3c23_row1_col21, #T_d3c23_row1_col30, #T_d3c23_row1_col31, #T_d3c23_row1_col34, #T_d3c23_row1_col37, #T_d3c23_row1_col39, #T_d3c23_row1_col43, #T_d3c23_row1_col45, #T_d3c23_row1_col47, #T_d3c23_row1_col48, #T_d3c23_row1_col49, #T_d3c23_row2_col0, #T_d3c23_row2_col2, #T_d3c23_row2_col7, #T_d3c23_row2_col8, #T_d3c23_row2_col9, #T_d3c23_row2_col15, #T_d3c23_row2_col17, #T_d3c23_row2_col18, #T_d3c23_row2_col19, #T_d3c23_row2_col20, #T_d3c23_row2_col22, #T_d3c23_row2_col25, #T_d3c23_row2_col28, #T_d3c23_row2_col33, #T_d3c23_row2_col44 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_d3c23_row0_col18 {
#   background-color: #c9e466;
#   color: #000000;
# }
# #T_d3c23_row0_col19, #T_d3c23_row0_col47, #T_d3c23_row1_col14, #T_d3c23_row2_col6 {
#   background-color: #7fbf66;
#   color: #000000;
# }
# #T_d3c23_row0_col22, #T_d3c23_row1_col23, #T_d3c23_row2_col32 {
#   background-color: #55aa66;
#   color: #f1f1f1;
# }
# #T_d3c23_row0_col34 {
#   background-color: #dfef66;
#   color: #000000;
# }
# #T_d3c23_row1_col7 {
#   background-color: #45a266;
#   color: #f1f1f1;
# }
# #T_d3c23_row1_col8 {
#   background-color: #41a066;
#   color: #f1f1f1;
# }
# #T_d3c23_row1_col17 {
#   background-color: #d1e866;
#   color: #000000;
# }
# #T_d3c23_row1_col20 {
#   background-color: #88c366;
#   color: #000000;
# }
# #T_d3c23_row1_col24 {
#   background-color: #118866;
#   color: #f1f1f1;
# }
# #T_d3c23_row1_col41 {
#   background-color: #8ec666;
#   color: #000000;
# }
# #T_d3c23_row1_col44 {
#   background-color: #249266;
#   color: #f1f1f1;
# }
# #T_d3c23_row2_col1 {
#   background-color: #3f9f66;
#   color: #f1f1f1;
# }
# #T_d3c23_row2_col4 {
#   background-color: #edf666;
#   color: #000000;
# }
# #T_d3c23_row2_col5 {
#   background-color: #66b266;
#   color: #f1f1f1;
# }
# #T_d3c23_row2_col10 {
#   background-color: #97cb66;
#   color: #000000;
# }
# #T_d3c23_row2_col11 {
#   background-color: #b2d866;
#   color: #000000;
# }
# #T_d3c23_row2_col12 {
#   background-color: #7cbe66;
#   color: #000000;
# }
# #T_d3c23_row2_col29 {
#   background-color: #f8fc66;
#   color: #000000;
# }
# #T_d3c23_row2_col36 {
#   background-color: #d5ea66;
#   color: #000000;
# }
# #T_d3c23_row2_col38 {
#   background-color: #5aac66;
#   color: #f1f1f1;
# }
# #T_d3c23_row2_col40 {
#   background-color: #aad466;
#   color: #000000;
# }
# </style>
# <table id="T_d3c23">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Age</th>
#       <th id="T_d3c23_level0_col0" class="col_heading level0 col0" >10</th>
#       <th id="T_d3c23_level0_col1" class="col_heading level0 col1" >12</th>
#       <th id="T_d3c23_level0_col2" class="col_heading level0 col2" >13</th>
#       <th id="T_d3c23_level0_col3" class="col_heading level0 col3" >14</th>
#       <th id="T_d3c23_level0_col4" class="col_heading level0 col4" >15</th>
#       <th id="T_d3c23_level0_col5" class="col_heading level0 col5" >16</th>
#       <th id="T_d3c23_level0_col6" class="col_heading level0 col6" >17</th>
#       <th id="T_d3c23_level0_col7" class="col_heading level0 col7" >18</th>
#       <th id="T_d3c23_level0_col8" class="col_heading level0 col8" >19</th>
#       <th id="T_d3c23_level0_col9" class="col_heading level0 col9" >20</th>
#       <th id="T_d3c23_level0_col10" class="col_heading level0 col10" >21</th>
#       <th id="T_d3c23_level0_col11" class="col_heading level0 col11" >22</th>
#       <th id="T_d3c23_level0_col12" class="col_heading level0 col12" >23</th>
#       <th id="T_d3c23_level0_col13" class="col_heading level0 col13" >24</th>
#       <th id="T_d3c23_level0_col14" class="col_heading level0 col14" >25</th>
#       <th id="T_d3c23_level0_col15" class="col_heading level0 col15" >26</th>
#       <th id="T_d3c23_level0_col16" class="col_heading level0 col16" >27</th>
#       <th id="T_d3c23_level0_col17" class="col_heading level0 col17" >28</th>
#       <th id="T_d3c23_level0_col18" class="col_heading level0 col18" >29</th>
#       <th id="T_d3c23_level0_col19" class="col_heading level0 col19" >30</th>
#       <th id="T_d3c23_level0_col20" class="col_heading level0 col20" >31</th>
#       <th id="T_d3c23_level0_col21" class="col_heading level0 col21" >32</th>
#       <th id="T_d3c23_level0_col22" class="col_heading level0 col22" >33</th>
#       <th id="T_d3c23_level0_col23" class="col_heading level0 col23" >34</th>
#       <th id="T_d3c23_level0_col24" class="col_heading level0 col24" >35</th>
#       <th id="T_d3c23_level0_col25" class="col_heading level0 col25" >36</th>
#       <th id="T_d3c23_level0_col26" class="col_heading level0 col26" >37</th>
#       <th id="T_d3c23_level0_col27" class="col_heading level0 col27" >38</th>
#       <th id="T_d3c23_level0_col28" class="col_heading level0 col28" >39</th>
#       <th id="T_d3c23_level0_col29" class="col_heading level0 col29" >40</th>
#       <th id="T_d3c23_level0_col30" class="col_heading level0 col30" >41</th>
#       <th id="T_d3c23_level0_col31" class="col_heading level0 col31" >42</th>
#       <th id="T_d3c23_level0_col32" class="col_heading level0 col32" >43</th>
#       <th id="T_d3c23_level0_col33" class="col_heading level0 col33" >44</th>
#       <th id="T_d3c23_level0_col34" class="col_heading level0 col34" >45</th>
#       <th id="T_d3c23_level0_col35" class="col_heading level0 col35" >46</th>
#       <th id="T_d3c23_level0_col36" class="col_heading level0 col36" >48</th>
#       <th id="T_d3c23_level0_col37" class="col_heading level0 col37" >49</th>
#       <th id="T_d3c23_level0_col38" class="col_heading level0 col38" >50</th>
#       <th id="T_d3c23_level0_col39" class="col_heading level0 col39" >51</th>
#       <th id="T_d3c23_level0_col40" class="col_heading level0 col40" >54</th>
#       <th id="T_d3c23_level0_col41" class="col_heading level0 col41" >55</th>
#       <th id="T_d3c23_level0_col42" class="col_heading level0 col42" >56</th>
#       <th id="T_d3c23_level0_col43" class="col_heading level0 col43" >59</th>
#       <th id="T_d3c23_level0_col44" class="col_heading level0 col44" >60</th>
#       <th id="T_d3c23_level0_col45" class="col_heading level0 col45" >6

# %% [markdown]
# #### Key Observations for Age and Risk Levels:
#
# ---
#
#
#
# 1. **Age Distribution and Risk Levels**:
#    - **Low Risk**: Predominantly observed in individuals aged between 10 and 25 years, with a peak in the early 20s.
#    - **Mid Risk**: Most common in individuals aged 20 to 35 years, peaking in the late 20s to early 30s.
#    - **High Risk**: Noticeably higher in individuals aged 35 and above, with significant cases starting from 40 years, and peaking around the age of 50.
#
# 2. **Risk Level Transitions with Age**:
#    - **Below 25 years**: Majority are at low risk, with minimal mid or high-risk cases.
#    - **25 to 35 years**: Increase in mid-risk cases, and a decrease in low-risk cases.
#    - **Above 35 years**: Significant rise in high-risk cases, low-risk cases diminish.
#
# 3. **Density Estimates**:
#    - **Low Risk**: Sharp peak around early 20s.
#    - **Mid Risk**: Peaks in late 20s to early 30s.
#    - **High Risk**: Rises steadily from late 30s, peaking around 50 years.
#
# 4. **Overlap and Transition Periods**:
#    - Notable overlap of low and mid-risk categories in the 20-25 age range.
#    - Significant overlap of mid and high-risk categories from the late 30s to 40s.
#
#
#
# **Age-Related Health Risks**:
#    - Age is a crucial factor in determining health risk levels. Younger individuals are generally at low risk, whereas older individuals are more likely to be at high risk.

# %% [markdown]
# #### SystolicBP → RiskLevel

# %%
sns.histplot(data=df, x="SystolicBP", hue="RiskLevel", kde=True, hue_order=risk_order, palette=p_colors)
plt.show()

# %%
pd.crosstab(df.RiskLevel, df.SystolicBP).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_39595_row0_col0, #T_39595_row0_col1, #T_39595_row0_col2, #T_39595_row0_col3, #T_39595_row0_col4, #T_39595_row0_col7, #T_39595_row0_col8, #T_39595_row0_col9, #T_39595_row0_col10, #T_39595_row0_col12, #T_39595_row0_col13, #T_39595_row0_col14, #T_39595_row1_col5, #T_39595_row1_col6, #T_39595_row1_col11, #T_39595_row1_col12, #T_39595_row1_col15, #T_39595_row1_col16, #T_39595_row1_col17, #T_39595_row1_col18, #T_39595_row2_col1, #T_39595_row2_col2, #T_39595_row2_col3, #T_39595_row2_col4, #T_39595_row2_col5, #T_39595_row2_col9, #T_39595_row2_col14, #T_39595_row2_col16, #T_39595_row2_col18 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_39595_row0_col5, #T_39595_row0_col16, #T_39595_row0_col17, #T_39595_row0_col18, #T_39595_row1_col0, #T_39595_row1_col1, #T_39595_row1_col2, #T_39595_row1_col3, #T_39595_row1_col4, #T_39595_row1_col7, #T_39595_row1_col8, #T_39595_row1_col9, #T_39595_row1_col10, #T_39595_row1_col13, #T_39595_row1_col14, #T_39595_row2_col6, #T_39595_row2_col11, #T_39595_row2_col12, #T_39595_row2_col15 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_39595_row0_col6, #T_39595_row0_col15 {
#   background-color: #bfdf66;
#   color: #000000;
# }
# #T_39595_row0_col11 {
#   background-color: #249266;
#   color: #f1f1f1;
# }
# #T_39595_row2_col0 {
#   background-color: #99cc66;
#   color: #000000;
# }
# #T_39595_row2_col7 {
#   background-color: #96cb66;
#   color: #000000;
# }
# #T_39595_row2_col8 {
#   background-color: #b6db66;
#   color: #000000;
# }
# #T_39595_row2_col10 {
#   background-color: #b7db66;
#   color: #000000;
# }
# #T_39595_row2_col13 {
#   background-color: #44a266;
#   color: #f1f1f1;
# }
# #T_39595_row2_col17 {
#   background-color: #f4fa66;
#   color: #000000;
# }
# </style>
# <table id="T_39595">
#   <thead>
#     <tr>
#       <th class="index_name level0" >SystolicBP</th>
#       <th id="T_39595_level0_col0" class="col_heading level0 col0" >70</th>
#       <th id="T_39595_level0_col1" class="col_heading level0 col1" >75</th>
#       <th id="T_39595_level0_col2" class="col_heading level0 col2" >76</th>
#       <th id="T_39595_level0_col3" class="col_heading level0 col3" >78</th>
#       <th id="T_39595_level0_col4" class="col_heading level0 col4" >80</th>
#       <th id="T_39595_level0_col5" class="col_heading level0 col5" >83</th>
#       <th id="T_39595_level0_col6" class="col_heading level0 col6" >85</th>
#       <th id="T_39595_level0_col7" class="col_heading level0 col7" >90</th>
#       <th id="T_39595_level0_col8" class="col_heading level0 col8" >95</th>
#       <th id="T_39595_level0_col9" class="col_heading level0 col9" >99</th>
#       <th id="T_39595_level0_col10" class="col_heading level0 col10" >100</th>
#       <th id="T_39595_level0_col11" class="col_heading level0 col11" >110</th>
#       <th id="T_39595_level0_col12" class="col_heading level0 col12" >115</th>
#       <th id="T_39595_level0_col13" class="col_heading level0 col13" >120</th>
#       <th id="T_39595_level0_col14" class="col_heading level0 col14" >129</th>
#       <th id="T_39595_level0_col15" class="col_heading level0 col15" >130</th>
#       <th id="T_39595_level0_col16" class="col_heading level0 col16" >135</th>
#       <th id="T_39595_level0_col17" class="col_heading level0 col17" >140</th>
#       <th id="T_39595_level0_col18" class="col_heading level0 col18" >160</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >RiskLevel</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_39595_level0_row0" class="row_heading level0 row0" >high risk</th>
#       <td id="T_39595_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_39595_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_39595_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_39595_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_39595_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_39595_row0_col5" class="data row0 col5" >2</td>
#       <td id="T_39595_row0_col6" class="data row0 col6" >13</td>
#       <td id="T_39595_row0_col7" class="data row0 col7" >33</td>
#       <td id="T_39595_row0_col8" class="data row0 col8" >1</td>
#       <td id="T_39595_row0_col9" class="data row0 col9" >0</td>
#       <td id="T_39595_row0_col10" class="data row0 col10" >5</td>
#       <td id="T_39595_row0_col11" class="data row0 col11" >8</td>
#       <td id="T_39595_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_39595_row0_col13" class="data row0 col13" >70</td>
#       <td id="T_39595_row0_col14" class="data row0 col14" >0</td>
#       <td id="T_39595_row0_col15" class="data row0 col15" >12</td>
#       <td id="T_39595_row0_col16" class="data row0 col16" >3</td>
#       <td id="T_39595_row0_col17" class="data row0 col17" >115</td>
#       <td id="T_39595_row0_col18" class="data row0 col18" >10</td>
#     </tr>
#     <tr>
#       <th id="T_39595_level0_row1" class="row_heading level0 row1" >low risk</th>
#       <td id="T_39595_row1_col0" class="data row1 col0" >5</td>
#       <td id="T_39595_row1_col1" class="data row1 col1" >8</td>
#       <td id="T_39595_row1_col2" class="data row1 col2" >16</td>
#       <td id="T_39595_row1_col3" class="data row1 col3" >3</td>
#       <td id="T_39595_row1_col4" class="data row1 col4" >5</td>
#       <td id="T_39595_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_39595_row1_col6" class="data row1 col6" >11</td>
#       <td id="T_39595_row1_col7" class="data row1 col7" >72</td>
#       <td id="T_39595_row1_col8" class="data row1 col8" >8</td>
#       <td id="T_39595_row1_col9" class="data row1 col9" >2</td>
#       <td id="T_39595_row1_col10" class="data row1 col10" >65</td>
#       <td id="T_39595_row1_col11" class="data row1 col11" >2</td>
#       <td id="T_39595_row1_col12" class="data row1 col12" >0</td>
#       <td id="T_39595_row1_col13" class="data row1 col13" >208</td>
#       <td id="T_39595_row1_col14" class="data row1 col14" >1</td>
#       <td id="T_39595_row1_col15" class="data row1 col15" >0</td>
#       <td id="T_39595_row1_col16" class="data row1 col16" >0</td>
#       <td id="T_39595_row1_col17" class="data row1 col17" >0</td>
#       <td id="T_39595_row1_col18" class="data row1 col18" >0</td>
#     </tr>
#     <tr>
#       <th id="T_39595_level0_row2" class="row_heading level0 row2" >mid risk</th>
#       <td id="T_39595_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_39595_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_39595_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_39595_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_39595_row2_col4" class="data row2 col4" >0</td>
#       <td id="T_39595_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_39595_row2_col6" class="data row2 col6" >19</td>
#       <td id="T_39595_row2_col7" class="data row2 col7" >49</td>
#       <td id="T_39595_row2_col8" class="data row2 col8" >3</td>
#       <td id="T_39595_row2_col9" class="data row2 col9" >0</td>
#       <td id="T_39595_row2_col10" class="data row2 col10" >22</td>
#       <td id="T_39595_row2_col11" class="data row2 col11" >9</td>
#       <td id="T_39595_row2_col12" class="data row2 col12" >8</td>
#       <td id="T_39595_row2_col13" class="data row2 col13" >171</td>
#       <td id="T_39595_row2_col14" class="data row2 col14" >0</td>
#       <td id="T_39595_row2_col15" class="data row2 col15" >48</td>
#       <td

# %% [markdown]
# #### Key Observations for Systolic Blood Pressure (SystolicBP) and Risk Levels:
#
# ---
#
#
#
# 1. **SystolicBP Distribution and Risk Levels**:
#    - **Low Risk**: Predominantly seen in individuals with SystolicBP around 120 mmHg. Noticeable peaks are also observed at lower SystolicBP values (80-100 mmHg).
#    - **Mid Risk**: Commonly seen in the SystolicBP range of 100-130 mmHg. Peaks are less pronounced but spread across this range.
#    - **High Risk**: Clearly observed in individuals with SystolicBP above 140 mmHg. There is a significant peak at around 140 mmHg.
#
# 2. **Risk Level Transitions with SystolicBP**:
#    - **Below 100 mmHg**: Mostly low risk, with a few mid-risk and high-risk cases.
#    - **100-130 mmHg**: Increase in mid-risk cases, indicating a transition zone where risk levels start to rise.
#    - **Above 130 mmHg**: Significant rise in high-risk cases, especially around 140 mmHg and above.
#
# 3. **Density Estimates**:
#    - **Low Risk**: Sharp peak at 120 mmHg, with secondary peaks at lower pressures.
#    - **Mid Risk**: Multiple small peaks across the 100-130 mmHg range.
#    - **High Risk**: Prominent peak at around 140 mmHg, with a gradual rise starting from 130 mmHg.
#
# 4. **Overlap and Transition Periods**:
#    - Notable overlap of low and mid-risk categories around 100-130 mmHg, indicating a critical range where monitoring and intervention might be necessary.
#    - Significant overlap of mid and high-risk categories from 130 mmHg onwards, highlighting a zone of increased health risk.
#
#
# **Blood Pressure-Related Health Risks**:
#    - Systolic blood pressure is a crucial factor in determining health risk levels. Lower SystolicBP is generally associated with low risk, while higher SystolicBP is linked to increased risk levels.

# %% [markdown]
# #### DiastolicBP → RiskLevel

# %%
sns.histplot(data=df, x="DiastolicBP", hue="RiskLevel", kde=True, hue_order=risk_order, palette=p_colors)
plt.show()

# %%
pd.crosstab(df.RiskLevel, df.DiastolicBP).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_144cb_row0_col0, #T_144cb_row0_col1, #T_144cb_row0_col2, #T_144cb_row0_col3, #T_144cb_row0_col4, #T_144cb_row0_col5, #T_144cb_row0_col7, #T_144cb_row0_col9, #T_144cb_row0_col10, #T_144cb_row0_col11, #T_144cb_row0_col12, #T_144cb_row1_col3, #T_144cb_row1_col6, #T_144cb_row1_col15, #T_144cb_row2_col0, #T_144cb_row2_col5, #T_144cb_row2_col6, #T_144cb_row2_col8, #T_144cb_row2_col9, #T_144cb_row2_col12, #T_144cb_row2_col13, #T_144cb_row2_col14 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_144cb_row0_col6, #T_144cb_row0_col14, #T_144cb_row0_col15, #T_144cb_row1_col0, #T_144cb_row1_col1, #T_144cb_row1_col2, #T_144cb_row1_col4, #T_144cb_row1_col5, #T_144cb_row1_col8, #T_144cb_row1_col9, #T_144cb_row1_col10, #T_144cb_row1_col11, #T_144cb_row1_col12, #T_144cb_row1_col13, #T_144cb_row2_col3, #T_144cb_row2_col7 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_144cb_row0_col8 {
#   background-color: #bfdf66;
#   color: #000000;
# }
# #T_144cb_row0_col13 {
#   background-color: #e8f466;
#   color: #000000;
# }
# #T_144cb_row1_col7, #T_144cb_row2_col4 {
#   background-color: #55aa66;
#   color: #f1f1f1;
# }
# #T_144cb_row1_col14 {
#   background-color: #bcde66;
#   color: #000000;
# }
# #T_144cb_row2_col1 {
#   background-color: #7fbf66;
#   color: #000000;
# }
# #T_144cb_row2_col2 {
#   background-color: #3e9e66;
#   color: #f1f1f1;
# }
# #T_144cb_row2_col10 {
#   background-color: #118866;
#   color: #f1f1f1;
# }
# #T_144cb_row2_col11 {
#   background-color: #a4d266;
#   color: #000000;
# }
# #T_144cb_row2_col15 {
#   background-color: #eff766;
#   color: #000000;
# }
# </style>
# <table id="T_144cb">
#   <thead>
#     <tr>
#       <th class="index_name level0" >DiastolicBP</th>
#       <th id="T_144cb_level0_col0" class="col_heading level0 col0" >49</th>
#       <th id="T_144cb_level0_col1" class="col_heading level0 col1" >50</th>
#       <th id="T_144cb_level0_col2" class="col_heading level0 col2" >60</th>
#       <th id="T_144cb_level0_col3" class="col_heading level0 col3" >63</th>
#       <th id="T_144cb_level0_col4" class="col_heading level0 col4" >65</th>
#       <th id="T_144cb_level0_col5" class="col_heading level0 col5" >68</th>
#       <th id="T_144cb_level0_col6" class="col_heading level0 col6" >69</th>
#       <th id="T_144cb_level0_col7" class="col_heading level0 col7" >70</th>
#       <th id="T_144cb_level0_col8" class="col_heading level0 col8" >75</th>
#       <th id="T_144cb_level0_col9" class="col_heading level0 col9" >76</th>
#       <th id="T_144cb_level0_col10" class="col_heading level0 col10" >80</th>
#       <th id="T_144cb_level0_col11" class="col_heading level0 col11" >85</th>
#       <th id="T_144cb_level0_col12" class="col_heading level0 col12" >89</th>
#       <th id="T_144cb_level0_col13" class="col_heading level0 col13" >90</th>
#       <th id="T_144cb_level0_col14" class="col_heading level0 col14" >95</th>
#       <th id="T_144cb_level0_col15" class="col_heading level0 col15" >100</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >RiskLevel</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_144cb_level0_row0" class="row_heading level0 row0" >high risk</th>
#       <td id="T_144cb_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_144cb_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_144cb_row0_col2" class="data row0 col2" >34</td>
#       <td id="T_144cb_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_144cb_row0_col4" class="data row0 col4" >14</td>
#       <td id="T_144cb_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_144cb_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_144cb_row0_col7" class="data row0 col7" >10</td>
#       <td id="T_144cb_row0_col8" class="data row0 col8" >12</td>
#       <td id="T_144cb_row0_col9" class="data row0 col9" >0</td>
#       <td id="T_144cb_row0_col10" class="data row0 col10" >38</td>
#       <td id="T_144cb_row0_col11" class="data row0 col11" >10</td>
#       <td id="T_144cb_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_144cb_row0_col13" class="data row0 col13" >48</td>
#       <td id="T_144cb_row0_col14" class="data row0 col14" >23</td>
#       <td id="T_144cb_row0_col15" class="data row0 col15" >80</td>
#     </tr>
#     <tr>
#       <th id="T_144cb_level0_row1" class="row_heading level0 row1" >low risk</th>
#       <td id="T_144cb_row1_col0" class="data row1 col0" >25</td>
#       <td id="T_144cb_row1_col1" class="data row1 col1" >16</td>
#       <td id="T_144cb_row1_col2" class="data row1 col2" >75</td>
#       <td id="T_144cb_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_144cb_row1_col4" class="data row1 col4" >41</td>
#       <td id="T_144cb_row1_col5" class="data row1 col5" >2</td>
#       <td id="T_144cb_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_144cb_row1_col7" class="data row1 col7" >38</td>
#       <td id="T_144cb_row1_col8" class="data row1 col8" >15</td>
#       <td id="T_144cb_row1_col9" class="data row1 col9" >3</td>
#       <td id="T_144cb_row1_col10" class="data row1 col10" >96</td>
#       <td id="T_144cb_row1_col11" class="data row1 col11" >24</td>
#       <td id="T_144cb_row1_col12" class="data row1 col12" >1</td>
#       <td id="T_144cb_row1_col13" class="data row1 col13" >58</td>
#       <td id="T_144cb_row1_col14" class="data row1 col14" >9</td>
#       <td id="T_144cb_row1_col15" class="data row1 col15" >1</td>
#     </tr>
#     <tr>
#       <th id="T_144cb_level0_row2" class="row_heading level0 row2" >mid risk</th>
#       <td id="T_144cb_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_144cb_row2_col1" class="data row2 col1" >8</td>
#       <td id="T_144cb_row2_col2" class="data row2 col2" >65</td>
#       <td id="T_144cb_row2_col3" class="data row2 col3" >4</td>
#       <td id="T_144cb_row2_col4" class="data row2 col4" >32</td>
#       <td id="T_144cb_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_144cb_row2_col6" class="data row2 col6" >0</td>
#       <td id="T_144cb_row2_col7" class="data row2 col7" >52</td>
#       <td id="T_144cb_row2_col8" class="data row2 col8" >11</td>
#       <td id="T_144cb_row2_col9" class="data row2 col9" >0</td>
#       <td id="T_144cb_row2_col10" class="data row2 col10" >92</td>
#       <td id="T_144cb_row2_col11" class="data row2 col11" >15</td>
#       <td id="T_144cb_row2_col12" class="data row2 col12" >0</td>
#       <td id="T_144cb_row2_col13" class="data row2 col13" >47</td>
#       <td id="T_144cb_row2_col14" class="data row2 col14" >4</td>
#       <td id="T_144cb_row2_col15" class="data row2 col15" >6</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Key Observations for Diastolic Blood Pressure (DiastolicBP) and Risk Levels:
#
# ---
#
#
#
# 1. **DiastolicBP Distribution and Risk Levels**:
#    - **Low Risk**: Predominantly seen in individuals with diastolic blood pressure (DiastolicBP) around 60-80 mmHg. There are noticeable peaks at 60 mmHg, 70 mmHg, and 80 mmHg.
#    - **Mid Risk**: Commonly observed in the DiastolicBP range of 70-80 mmHg. There is a peak around 70 mmHg.
#    - **High Risk**: Clearly observed in individuals with DiastolicBP of 100 mmHg, with a significant peak at this value.
#
# 2. **Risk Level Transitions with DiastolicBP**:
#    - **Below 70 mmHg**: Mostly low risk, with a few mid-risk cases and very few high-risk cases.
#    - **70-80 mmHg**: Transition zone where the number of mid-risk cases increases. There is an overlap of low and mid-risk categories.
#    - **Above 80 mmHg**: Significant rise in high-risk cases, especially at 100 mmHg.
#
# 3. **Density Estimates**:
#    - **Low Risk**: Peaks around 60 mmHg and 80 mmHg, with secondary peaks at other intervals.
#    - **Mid Risk**: Peaks at 70 mmHg, indicating a transition zone.
#    - **High Risk**: Prominent peak at around 100 mmHg, with a gradual rise starting from 80 mmHg.
#
# 4. **Overlap and Transition Periods**:
#    - Notable overlap of low and mid-risk categories around 70-80 mmHg, indicating a critical range where monitoring and intervention might be necessary.
#    - Significant overlap of mid and high-risk categories from 80 mmHg onwards, highlighting a zone of increased health risk.
#
#
#
# **Blood Pressure-Related Health Risks**:
#    - Diastolic blood pressure is a crucial factor in determining health risk levels. Lower DiastolicBP is generally associated with low risk, while higher DiastolicBP is linked to increased risk levels.

# %% [markdown]
# #### BS → RiskLevel

# %%
sns.histplot(data=df, x="BS", hue="RiskLevel", kde=True, hue_order=risk_order, palette=p_colors)
plt.show()

# %%
pd.crosstab(df.RiskLevel, df.BS).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_d39f4_row0_col0, #T_d39f4_row0_col1, #T_d39f4_row0_col3, #T_d39f4_row0_col4, #T_d39f4_row0_col5, #T_d39f4_row0_col6, #T_d39f4_row0_col7, #T_d39f4_row0_col8, #T_d39f4_row0_col9, #T_d39f4_row0_col11, #T_d39f4_row0_col13, #T_d39f4_row0_col14, #T_d39f4_row0_col16, #T_d39f4_row0_col17, #T_d39f4_row1_col2, #T_d39f4_row1_col10, #T_d39f4_row1_col18, #T_d39f4_row1_col19, #T_d39f4_row1_col20, #T_d39f4_row1_col21, #T_d39f4_row1_col22, #T_d39f4_row1_col23, #T_d39f4_row1_col24, #T_d39f4_row1_col25, #T_d39f4_row1_col26, #T_d39f4_row1_col27, #T_d39f4_row1_col28, #T_d39f4_row2_col2, #T_d39f4_row2_col4, #T_d39f4_row2_col5, #T_d39f4_row2_col11, #T_d39f4_row2_col12, #T_d39f4_row2_col14, #T_d39f4_row2_col15, #T_d39f4_row2_col20, #T_d39f4_row2_col23, #T_d39f4_row2_col26, #T_d39f4_row2_col28 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_d39f4_row0_col2, #T_d39f4_row0_col18, #T_d39f4_row0_col20, #T_d39f4_row0_col21, #T_d39f4_row0_col22, #T_d39f4_row0_col23, #T_d39f4_row0_col24, #T_d39f4_row0_col26, #T_d39f4_row0_col27, #T_d39f4_row0_col28, #T_d39f4_row1_col1, #T_d39f4_row1_col3, #T_d39f4_row1_col4, #T_d39f4_row1_col5, #T_d39f4_row1_col11, #T_d39f4_row1_col12, #T_d39f4_row1_col13, #T_d39f4_row1_col14, #T_d39f4_row1_col15, #T_d39f4_row1_col17, #T_d39f4_row2_col0, #T_d39f4_row2_col6, #T_d39f4_row2_col7, #T_d39f4_row2_col8, #T_d39f4_row2_col9, #T_d39f4_row2_col10, #T_d39f4_row2_col16, #T_d39f4_row2_col19, #T_d39f4_row2_col25 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_d39f4_row0_col10, #T_d39f4_row1_col0, #T_d39f4_row2_col22 {
#   background-color: #7fbf66;
#   color: #000000;
# }
# #T_d39f4_row0_col12 {
#   background-color: #92c866;
#   color: #000000;
# }
# #T_d39f4_row0_col15 {
#   background-color: #edf666;
#   color: #000000;
# }
# #T_d39f4_row0_col19 {
#   background-color: #5eae66;
#   color: #f1f1f1;
# }
# #T_d39f4_row0_col25 {
#   background-color: #1c8e66;
#   color: #f1f1f1;
# }
# #T_d39f4_row1_col6 {
#   background-color: #90c866;
#   color: #000000;
# }
# #T_d39f4_row1_col7 {
#   background-color: #219066;
#   color: #f1f1f1;
# }
# #T_d39f4_row1_col8 {
#   background-color: #389c66;
#   color: #f1f1f1;
# }
# #T_d39f4_row1_col9 {
#   background-color: #5faf66;
#   color: #f1f1f1;
# }
# #T_d39f4_row1_col16 {
#   background-color: #1f8f66;
#   color: #f1f1f1;
# }
# #T_d39f4_row2_col1 {
#   background-color: #6eb666;
#   color: #f1f1f1;
# }
# #T_d39f4_row2_col3, #T_d39f4_row2_col18 {
#   background-color: #bfdf66;
#   color: #000000;
# }
# #T_d39f4_row2_col13 {
#   background-color: #c9e466;
#   color: #000000;
# }
# #T_d39f4_row2_col17 {
#   background-color: #e8f466;
#   color: #000000;
# }
# #T_d39f4_row2_col21 {
#   background-color: #e3f166;
#   color: #000000;
# }
# #T_d39f4_row2_col24 {
#   background-color: #e5f266;
#   color: #000000;
# }
# #T_d39f4_row2_col27 {
#   background-color: #d7eb66;
#   color: #000000;
# }
# </style>
# <table id="T_d39f4">
#   <thead>
#     <tr>
#       <th class="index_name level0" >BS</th>
#       <th id="T_d39f4_level0_col0" class="col_heading level0 col0" >6.000000</th>
#       <th id="T_d39f4_level0_col1" class="col_heading level0 col1" >6.100000</th>
#       <th id="T_d39f4_level0_col2" class="col_heading level0 col2" >6.300000</th>
#       <th id="T_d39f4_level0_col3" class="col_heading level0 col3" >6.400000</th>
#       <th id="T_d39f4_level0_col4" class="col_heading level0 col4" >6.500000</th>
#       <th id="T_d39f4_level0_col5" class="col_heading level0 col5" >6.600000</th>
#       <th id="T_d39f4_level0_col6" class="col_heading level0 col6" >6.700000</th>
#       <th id="T_d39f4_level0_col7" class="col_heading level0 col7" >6.800000</th>
#       <th id="T_d39f4_level0_col8" class="col_heading level0 col8" >6.900000</th>
#       <th id="T_d39f4_level0_col9" class="col_heading level0 col9" >7.000000</th>
#       <th id="T_d39f4_level0_col10" class="col_heading level0 col10" >7.010000</th>
#       <th id="T_d39f4_level0_col11" class="col_heading level0 col11" >7.100000</th>
#       <th id="T_d39f4_level0_col12" class="col_heading level0 col12" >7.200000</th>
#       <th id="T_d39f4_level0_col13" class="col_heading level0 col13" >7.500000</th>
#       <th id="T_d39f4_level0_col14" class="col_heading level0 col14" >7.600000</th>
#       <th id="T_d39f4_level0_col15" class="col_heading level0 col15" >7.700000</th>
#       <th id="T_d39f4_level0_col16" class="col_heading level0 col16" >7.800000</th>
#       <th id="T_d39f4_level0_col17" class="col_heading level0 col17" >7.900000</th>
#       <th id="T_d39f4_level0_col18" class="col_heading level0 col18" >8.000000</th>
#       <th id="T_d39f4_level0_col19" class="col_heading level0 col19" >9.000000</th>
#       <th id="T_d39f4_level0_col20" class="col_heading level0 col20" >10.000000</th>
#       <th id="T_d39f4_level0_col21" class="col_heading level0 col21" >11.000000</th>
#       <th id="T_d39f4_level0_col22" class="col_heading level0 col22" >12.000000</th>
#       <th id="T_d39f4_level0_col23" class="col_heading level0 col23" >13.000000</th>
#       <th id="T_d39f4_level0_col24" class="col_heading level0 col24" >15.000000</th>
#       <th id="T_d39f4_level0_col25" class="col_heading level0 col25" >16.000000</th>
#       <th id="T_d39f4_level0_col26" class="col_heading level0 col26" >17.000000</th>
#       <th id="T_d39f4_level0_col27" class="col_heading level0 col27" >18.000000</th>
#       <th id="T_d39f4_level0_col28" class="col_heading level0 col28" >19.000000</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >RiskLevel</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#       <th class="blank col23" >&nbsp;</th>
#       <th class="blank col24" >&nbsp;</th>
#       <th class="blank col25" >&nbsp;</th>
#       <th class="blank col26" >&nbsp;</th>
#       <th class="blank col27" >&nbsp;</th>
#       <th class="blank col28" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d39f4_level0_row0" class="row_heading level0 row0" >high risk</th>
#       <td id="T_d39f4_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_d39f4_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_d39f4_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_d39f4_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_d39f4_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_d39f4_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_d39f4_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_d39f4_row0_col7" class="data row0 col7" >10</td>
#       <td id="T_d39f4_row0_col8" class="data row0 col8" >8</td>
#       <td id="T_d39f4_row0_col9" class="data row0 col9" >9</td>
#       <td id="T_d39f4_row0_col10" class="data row0 col10" >5</td>
#       <td id="T_d39f4_row0_col11" class="data row0 col11" >0</td>
#       <td id="T_d39f4_row0_col12" class="data row0 col12" >6</td>
#       <td id="T_d39f4_row0_col13" class="data row0 col13" >11</td>
#       <td id="T_d39f4_row0_col14" class="data row0 col14" >0</td>
#       <td id="T_d39f4_row0_col15" class="data row0 col15" >4</td>
#       <td id="T_d39f4_row0_col16" class="data row0 col16" >5</td>
#       <td id="T_d39f4_row0_col17" class="data row0 col17" >12</td>
#       <td id="T_d39f4_row0_col18" class="data row0 col18" >12</td>
#       <td id="T_d39f4_row0_col19" class="

# %% [markdown]
# #### Key Observations for Blood Sugar (BS) and Risk Levels:
#
# ---
#
#
#
# 1. **BS Distribution and Risk Levels**:
#    - **Low Risk**: Predominantly seen in individuals with blood sugar (BS) levels around 6 to 8 mmol/L. There is a sharp peak at 7 mmol/L.
#    - **Mid Risk**: Observed in the BS range of 6 to 8 mmol/L, with a peak around 7 mmol/L.
#    - **High Risk**: Clearly observed in individuals with BS levels above 10 mmol/L, with several peaks at 12, 14, and 16 mmol/L.
#
# 2. **Risk Level Transitions with BS**:
#    - **Below 6 mmol/L**: Mostly low risk, with very few mid or high-risk cases.
#    - **6 to 8 mmol/L**: Transition zone where the number of mid-risk cases increases, and low-risk cases are predominant.
#    - **Above 10 mmol/L**: Significant rise in high-risk cases, indicating severe health risks associated with higher BS levels.
#
# 3. **Density Estimates**:
#    - **Low Risk**: Sharp peak around 7 mmol/L, indicating a concentration of low-risk individuals in this range.
#    - **Mid Risk**: Peaks at 7 mmol/L, showing overlap with low-risk individuals.
#    - **High Risk**: Multiple peaks at higher BS values (12, 14, 16 mmol/L), indicating that higher BS levels are strongly associated with high health risks.
#
# 4. **Overlap and Transition Periods**:
#    - Notable overlap of low and mid-risk categories around 6 to 8 mmol/L, indicating a critical range for monitoring and intervention.
#    - High-risk cases become predominant above 10 mmol/L, with minimal overlap with low or mid-risk categories.
#
#
# **Blood Sugar-Related Health Risks**:
#    - Blood sugar levels are a crucial factor in determining health risk levels. Lower BS levels (6-8 mmol/L) are generally associated with low risk, while higher BS levels (above 10 mmol/L) are linked to increased health risks.

# %% [markdown]
# #### BodyTemp → RiskLevel

# %%
sns.histplot(data=df, x="BodyTemp", hue="RiskLevel", kde=True, hue_order=risk_order, palette=p_colors)
plt.show()

# %%
pd.crosstab(df.RiskLevel, df.BodyTemp).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_127df_row0_col0, #T_127df_row0_col1, #T_127df_row0_col3, #T_127df_row1_col2, #T_127df_row1_col4, #T_127df_row1_col5, #T_127df_row1_col6, #T_127df_row2_col1, #T_127df_row2_col2, #T_127df_row2_col3, #T_127df_row2_col7 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_127df_row0_col2, #T_127df_row0_col6, #T_127df_row0_col7, #T_127df_row1_col0, #T_127df_row1_col1, #T_127df_row1_col3, #T_127df_row2_col4, #T_127df_row2_col5 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_127df_row0_col4 {
#   background-color: #badc66;
#   color: #000000;
# }
# #T_127df_row0_col5 {
#   background-color: #71b866;
#   color: #f1f1f1;
# }
# #T_127df_row1_col7 {
#   background-color: #3f9f66;
#   color: #f1f1f1;
# }
# #T_127df_row2_col0 {
#   background-color: #b4da66;
#   color: #000000;
# }
# #T_127df_row2_col6 {
#   background-color: #49a466;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_127df">
#   <thead>
#     <tr>
#       <th class="index_name level0" >BodyTemp</th>
#       <th id="T_127df_level0_col0" class="col_heading level0 col0" >98.000000</th>
#       <th id="T_127df_level0_col1" class="col_heading level0 col1" >98.400000</th>
#       <th id="T_127df_level0_col2" class="col_heading level0 col2" >98.600000</th>
#       <th id="T_127df_level0_col3" class="col_heading level0 col3" >99.000000</th>
#       <th id="T_127df_level0_col4" class="col_heading level0 col4" >100.000000</th>
#       <th id="T_127df_level0_col5" class="col_heading level0 col5" >101.000000</th>
#       <th id="T_127df_level0_col6" class="col_heading level0 col6" >102.000000</th>
#       <th id="T_127df_level0_col7" class="col_heading level0 col7" >103.000000</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >RiskLevel</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_127df_level0_row0" class="row_heading level0 row0" >high risk</th>
#       <td id="T_127df_row0_col0" class="data row0 col0" >199</td>
#       <td id="T_127df_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_127df_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_127df_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_127df_row0_col4" class="data row0 col4" >5</td>
#       <td id="T_127df_row0_col5" class="data row0 col5" >34</td>
#       <td id="T_127df_row0_col6" class="data row0 col6" >25</td>
#       <td id="T_127df_row0_col7" class="data row0 col7" >6</td>
#     </tr>
#     <tr>
#       <th id="T_127df_level0_row1" class="row_heading level0 row1" >low risk</th>
#       <td id="T_127df_row1_col0" class="data row1 col0" >359</td>
#       <td id="T_127df_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_127df_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_127df_row1_col3" class="data row1 col3" >6</td>
#       <td id="T_127df_row1_col4" class="data row1 col4" >2</td>
#       <td id="T_127df_row1_col5" class="data row1 col5" >14</td>
#       <td id="T_127df_row1_col6" class="data row1 col6" >18</td>
#       <td id="T_127df_row1_col7" class="data row1 col7" >5</td>
#     </tr>
#     <tr>
#       <th id="T_127df_level0_row2" class="row_heading level0 row2" >mid risk</th>
#       <td id="T_127df_row2_col0" class="data row2 col0" >246</td>
#       <td id="T_127df_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_127df_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_127df_row2_col3" class="data row2 col3" >2</td>
#       <td id="T_127df_row2_col4" class="data row2 col4" >13</td>
#       <td id="T_127df_row2_col5" class="data row2 col5" >50</td>
#       <td id="T_127df_row2_col6" class="data row2 col6" >23</td>
#       <td id="T_127df_row2_col7" class="data row2 col7" >2</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Key Observations for Body Temperature (BodyTemp) and Risk Levels:
#
# ---
#
#
#
# 1. **BodyTemp Distribution and Risk Levels**:
#    - **Low Risk**: Predominantly seen in individuals with a body temperature around 98°F. This category has the highest count.
#    - **Mid Risk**: Commonly observed in the body temperature range of 100-101°F.
#    - **High Risk**: Noticeable in individuals with a body temperature of 101-103°F, but the counts are relatively low compared to lower body temperatures.
#
# 2. **Risk Level Transitions with BodyTemp**:
#    - **98°F**: Majority are at low risk, with some individuals at mid and high risk.
#    - **100-101°F**: Increase in mid-risk cases, indicating a transition zone where risk levels start to rise.
#    - **101-103°F**: Significant rise in high-risk cases, indicating increased health risks associated with higher body temperatures.
#
# 3. **Density Estimates**:
#    - **Low Risk**: Sharp peak at 98°F, indicating a concentration of low-risk individuals at this temperature.
#    - **Mid Risk**: Peaks at 100-101°F, showing overlap with low-risk individuals.
#    - **High Risk**: Peaks at 101-103°F, indicating higher body temperatures are associated with high health risks.
#
# 4. **Overlap and Transition Periods**:
#    - Notable overlap of low and mid-risk categories around 98-101°F, indicating a critical range for monitoring and intervention.
#    - High-risk cases become more prominent at temperatures above 101°F, with minimal overlap with low-risk categories.
#
#
#
# **Body Temperature-Related Health Risks**:
#    - Body temperature is a crucial factor in determining health risk levels. Lower body temperatures (98°F) are generally associated with low risk, while higher body temperatures (above 101°F) are linked to increased health risks.

# %% [markdown]
# #### HeartRate → RiskLevel

# %%
sns.histplot(data=df, x="HeartRate", hue="RiskLevel", kde=True, hue_order=risk_order, palette=p_colors)
plt.show()

# %%
pd.crosstab(df.RiskLevel, df.HeartRate).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_973e6_row0_col0, #T_973e6_row0_col1, #T_973e6_row0_col2, #T_973e6_row0_col5, #T_973e6_row0_col6, #T_973e6_row0_col7, #T_973e6_row0_col8, #T_973e6_row0_col12, #T_973e6_row1_col4, #T_973e6_row1_col5, #T_973e6_row1_col10, #T_973e6_row1_col13, #T_973e6_row1_col15, #T_973e6_row2_col0, #T_973e6_row2_col3, #T_973e6_row2_col7, #T_973e6_row2_col9, #T_973e6_row2_col11, #T_973e6_row2_col14, #T_973e6_row2_col15 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_973e6_row0_col3 {
#   background-color: #bbdd66;
#   color: #000000;
# }
# #T_973e6_row0_col4, #T_973e6_row0_col11, #T_973e6_row0_col14, #T_973e6_row0_col15, #T_973e6_row1_col0, #T_973e6_row1_col1, #T_973e6_row1_col3, #T_973e6_row1_col6, #T_973e6_row1_col7, #T_973e6_row1_col9, #T_973e6_row1_col12, #T_973e6_row2_col2, #T_973e6_row2_col4, #T_973e6_row2_col5, #T_973e6_row2_col8, #T_973e6_row2_col10, #T_973e6_row2_col13 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_973e6_row0_col9 {
#   background-color: #c1e066;
#   color: #000000;
# }
# #T_973e6_row0_col10 {
#   background-color: #c9e466;
#   color: #000000;
# }
# #T_973e6_row0_col13 {
#   background-color: #359a66;
#   color: #f1f1f1;
# }
# #T_973e6_row1_col2 {
#   background-color: #55aa66;
#   color: #f1f1f1;
# }
# #T_973e6_row1_col8 {
#   background-color: #078366;
#   color: #f1f1f1;
# }
# #T_973e6_row1_col11 {
#   background-color: #7fbf66;
#   color: #000000;
# }
# #T_973e6_row1_col14 {
#   background-color: #68b366;
#   color: #f1f1f1;
# }
# #T_973e6_row2_col1 {
#   background-color: #ecf666;
#   color: #000000;
# }
# #T_973e6_row2_col6 {
#   background-color: #4aa466;
#   color: #f1f1f1;
# }
# #T_973e6_row2_col12 {
#   background-color: #198c66;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_973e6">
#   <thead>
#     <tr>
#       <th class="index_name level0" >HeartRate</th>
#       <th id="T_973e6_level0_col0" class="col_heading level0 col0" >7</th>
#       <th id="T_973e6_level0_col1" class="col_heading level0 col1" >60</th>
#       <th id="T_973e6_level0_col2" class="col_heading level0 col2" >65</th>
#       <th id="T_973e6_level0_col3" class="col_heading level0 col3" >66</th>
#       <th id="T_973e6_level0_col4" class="col_heading level0 col4" >67</th>
#       <th id="T_973e6_level0_col5" class="col_heading level0 col5" >68</th>
#       <th id="T_973e6_level0_col6" class="col_heading level0 col6" >70</th>
#       <th id="T_973e6_level0_col7" class="col_heading level0 col7" >75</th>
#       <th id="T_973e6_level0_col8" class="col_heading level0 col8" >76</th>
#       <th id="T_973e6_level0_col9" class="col_heading level0 col9" >77</th>
#       <th id="T_973e6_level0_col10" class="col_heading level0 col10" >78</th>
#       <th id="T_973e6_level0_col11" class="col_heading level0 col11" >80</th>
#       <th id="T_973e6_level0_col12" class="col_heading level0 col12" >82</th>
#       <th id="T_973e6_level0_col13" class="col_heading level0 col13" >86</th>
#       <th id="T_973e6_level0_col14" class="col_heading level0 col14" >88</th>
#       <th id="T_973e6_level0_col15" class="col_heading level0 col15" >90</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >RiskLevel</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_973e6_level0_row0" class="row_heading level0 row0" >high risk</th>
#       <td id="T_973e6_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_973e6_row0_col1" class="data row0 col1" >20</td>
#       <td id="T_973e6_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_973e6_row0_col3" class="data row0 col3" >25</td>
#       <td id="T_973e6_row0_col4" class="data row0 col4" >5</td>
#       <td id="T_973e6_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_973e6_row0_col6" class="data row0 col6" >43</td>
#       <td id="T_973e6_row0_col7" class="data row0 col7" >6</td>
#       <td id="T_973e6_row0_col8" class="data row0 col8" >20</td>
#       <td id="T_973e6_row0_col9" class="data row0 col9" >25</td>
#       <td id="T_973e6_row0_col10" class="data row0 col10" >9</td>
#       <td id="T_973e6_row0_col11" class="data row0 col11" >48</td>
#       <td id="T_973e6_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_973e6_row0_col13" class="data row0 col13" >22</td>
#       <td id="T_973e6_row0_col14" class="data row0 col14" >30</td>
#       <td id="T_973e6_row0_col15" class="data row0 col15" >19</td>
#     </tr>
#     <tr>
#       <th id="T_973e6_level0_row1" class="row_heading level0 row1" >low risk</th>
#       <td id="T_973e6_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_973e6_row1_col1" class="data row1 col1" >33</td>
#       <td id="T_973e6_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_973e6_row1_col3" class="data row1 col3" >44</td>
#       <td id="T_973e6_row1_col4" class="data row1 col4" >2</td>
#       <td id="T_973e6_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_973e6_row1_col6" class="data row1 col6" >126</td>
#       <td id="T_973e6_row1_col7" class="data row1 col7" >7</td>
#       <td id="T_973e6_row1_col8" class="data row1 col8" >55</td>
#       <td id="T_973e6_row1_col9" class="data row1 col9" >56</td>
#       <td id="T_973e6_row1_col10" class="data row1 col10" >2</td>
#       <td id="T_973e6_row1_col11" class="data row1 col11" >39</td>
#       <td id="T_973e6_row1_col12" class="data row1 col12" >10</td>
#       <td id="T_973e6_row1_col13" class="data row1 col13" >7</td>
#       <td id="T_973e6_row1_col14" class="data row1 col14" >21</td>
#       <td id="T_973e6_row1_col15" class="data row1 col15" >0</td>
#     </tr>
#     <tr>
#       <th id="T_973e6_level0_row2" class="row_heading level0 row2" >mid risk</th>
#       <td id="T_973e6_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_973e6_row2_col1" class="data row2 col1" >21</td>
#       <td id="T_973e6_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_973e6_row2_col3" class="data row2 col3" >18</td>
#       <td id="T_973e6_row2_col4" class="data row2 col4" >5</td>
#       <td id="T_973e6_row2_col5" class="data row2 col5" >2</td>
#       <td id="T_973e6_row2_col6" class="data row2 col6" >102</td>
#       <td id="T_973e6_row2_col7" class="data row2 col7" >6</td>
#       <td id="T_973e6_row2_col8" class="data row2 col8" >56</td>
#       <td id="T_973e6_row2_col9" class="data row2 col9" >15</td>
#       <td id="T_973e6_row2_col10" class="data row2 col10" >35</td>
#       <td id="T_973e6_row2_col11" class="data row2 col11" >30</td>
#       <td id="T_973e6_row2_col12" class="data row2 col12" >9</td>
#       <td id="T_973e6_row2_col13" class="data row2 col13" >26</td>
#       <td id="T_973e6_row2_col14" class="data row2 col14" >8</td>
#       <td id="T_973e6_row2_col15" class="data row2 col15" >0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Key Observations for Heart Rate (HeartRate) and Risk Levels:
#
# ---
#
#
#
# 1. **HeartRate Distribution and Risk Levels**:
#    - **Low Risk**: Predominantly seen in individuals with a heart rate around 60-70 bpm. There is a sharp peak at 70 bpm.
#    - **Mid Risk**: Commonly observed in the heart rate range of 70-80 bpm.
#    - **High Risk**: Noticeable in individuals with heart rates around 80-90 bpm, with peaks at 80 bpm and 90 bpm.
#
# 2. **Risk Level Transitions with HeartRate**:
#    - **Below 60 bpm**: Mostly low risk, with very few mid or high-risk cases.
#    - **60-80 bpm**: Transition zone where the number of mid-risk cases increases. There is significant overlap with low-risk individuals.
#    - **Above 80 bpm**: Significant rise in high-risk cases, indicating increased health risks associated with higher heart rates.
#
# 3. **Density Estimates**:
#    - **Low Risk**: Sharp peak around 70 bpm, indicating a concentration of low-risk individuals at this heart rate.
#    - **Mid Risk**: Peaks at 70-80 bpm, showing overlap with low-risk individuals.
#    - **High Risk**: Peaks at 80-90 bpm, indicating higher heart rates are associated with higher health risks.
#
# 4. **Overlap and Transition Periods**:
#    - Notable overlap of low and mid-risk categories around 60-80 bpm, indicating a critical range for monitoring and intervention.
#    - High-risk cases become more prominent at heart rates above 80 bpm, with minimal overlap with low-risk categories.
#
#
#
# **Heart Rate-Related Health Risks**:
#    - Heart rate is a crucial factor in determining health risk levels. Lower heart rates (60-70 bpm) are generally associated with low risk, while higher heart rates (above 80 bpm) are linked to increased health risks.

# %% [markdown]
# ---
#
#
# **Age :** Understanding the relationship between age and risk helps to retain
# this feature despite regularization, especially since different age groups show different risk levels.
#
#
# ---
#
#
#
# **Systolic and Diastolic Blood Pressure:**Strong relationships with risk levels suggest these features should be retained. Their interaction might also be significant.
#
#
#
# ---
#
#
# **Blood Sugar (BS):** The clear increase in risk with higher BS levels makes it a crucial feature.
#
#
# ---
#
#
#
# **Body Temperature:** Different ranges of body temperature relate to different risk levels, which is important information for the model.
#
#
#
# ---
#
#
# **Heart Rate:** Even though heart rate shows significant overlaps, understanding its specific ranges associated with different risk levels helps in deciding its transformation or interaction with other features.
#
#
# ---
